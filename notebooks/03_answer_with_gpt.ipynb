# %%
# 03_answer_with_gpt.ipynb - ESG Biodiversity RAG Assistant
# SECTION 1: Imports & Setup
import os
import time
from pathlib import Path
from dotenv import load_dotenv
import chromadb
from sentence_transformers import SentenceTransformer
import openai

# Load environment variables
load_dotenv(dotenv_path="/Users/jfsg/biodiversity-rag-nlp/.env", override=True)
openai.api_key = os.getenv("OPENAI_API_KEY")

# Load ChromaDB client and collection
vector_db_path = Path("../data/vector_db")
chroma_client = chromadb.PersistentClient(path=str(vector_db_path))
collection = chroma_client.get_collection(name="biodiversity_docs")

# Load embedding model
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
# SECTION 2: Core Functions
def retrieve_relevant_chunks(query, top_k=5):
    query_embedding = embedding_model.encode(query).tolist()
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=top_k,
        include=["documents", "metadatas", "distances"]
    )
    chunks, citations = [], []
    for doc, meta, dist in zip(results["documents"][0], results["metadatas"][0], results["distances"][0]):
        similarity = 1 - dist
        citation = f"{meta['file_name']} | Chunk ID: {meta['chunk_id']} | Page: {meta.get('source_page', 'N/A')} | Similarity: {similarity:.4f}"
        chunks.append(doc)
        citations.append(citation)
    return chunks, citations

def compose_prompt(user_query, context_chunks):
    system_prompt = (
        "You are a helpful ESG research assistant. Answer using ONLY the provided context.\n"
        "Be precise and do not hallucinate. Format the answer in Markdown."
    )
    context_text = "\n\n".join([f"Context {i+1}:\n{chunk}" for i, chunk in enumerate(context_chunks)])
    return f"{system_prompt}\n\n### User Question:\n{user_query}\n\n### Context:\n{context_text}\n\n### Answer:"

def ask_gpt(prompt):
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are an expert assistant in ESG and biodiversity investing."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.3,
        max_tokens=1024
    )
    return response['choices'][0]['message']['content'].strip()

def answer_query_with_rag(user_query, top_k=5):
    print("\nRetrieving relevant documents...")
    chunks, citations = retrieve_relevant_chunks(user_query, top_k)
    print("Assembling prompt for GPT...")
    prompt = compose_prompt(user_query, chunks)
    print("Querying GPT...")
    answer = ask_gpt(prompt)
    print("\n--- Final Answer (Markdown Rendered Below) ---\n")
    print(answer)
    print("\n--- Bibliography ---\n")
    for i, citation in enumerate(citations):
        print(f"[{i+1}] {citation}")

# %%
# SECTION 3: Choose Execution Mode
# A. Single Static Question Mode
# user_query = "What are the financial risks of biodiversity loss for institutional investors?"
# answer_query_with_rag(user_query)

# B. Batch Mode - Multiple Questions
batch_queries = [
    "What are the financial risks of biodiversity loss for institutional investors?",
    "What is the role of TNFD in biodiversity risk disclosure?",
    "How can investors integrate biodiversity KPIs into portfolios?",
    "Examples of companies with high biodiversity risk exposure"
]
for q in batch_queries:
    print("\n" + "="*80)
    print(f"Question: {q}")
    print("="*80)
    answer_query_with_rag(q)

    # Pause to avoid hitting token limits
    time.sleep(10)  # ⏳ Wait 10 seconds before the next query
    

# C. Interactive Mode
# while True:
#     user_query = input("\nAsk a question (or 'exit' to quit): ")
#     if user_query.lower() == 'exit':
#         break
#     answer_query_with_rag(user_query)
# Out:
# ================================================================================
# Question: What are the financial risks of biodiversity loss for institutional investors?
# ================================================================================
#
# Retrieving relevant documents...
# Assembling prompt for GPT...
# Querying GPT...
#
# --- Final Answer (Markdown Rendered Below) ---
#
# The financial risks of biodiversity loss for institutional investors are multifaceted and can impact various industries at the company or portfolio level. These risks include:
#
# 1. **Operational or Supply-Chain Disruptions**: Companies that depend on ecosystem services or at-risk natural commodities may face operational or supply-chain disruptions due to biodiversity loss. Such disruptions can affect the share of revenues or assets of these companies.
#
# 2. **Regulatory, Legal, or Reputational Risks**: As the business environment evolves, companies may face transition risks related to regulatory, legal, or reputational issues. These risks can affect the share of revenues or assets of companies that are exposed to them.
#
# 3. **Physical Risks**: Companies may be exposed to a range of nature-related physical risks, such as disturbances to land and marine areas, high water intensity, or high toxic emissions and waste intensity.
#
# 4. **Transition Risks**: Companies may also be exposed to nature-related transition risks, such as potential disturbances to land and marine areas, high water intensity, or high toxic emissions and waste intensity.
#
# 5. **Direct Impact on Biodiversity**: Companies that operate in biodiversity-sensitive areas or contribute to deforestation, either directly or indirectly, can face financial risks. These risks can be identified by assessing the company's operations, products, or controversies associated with alleged impact on biodiversity/nature.
#
# 6. **Dependence on Natural Commodities**: Companies that depend on natural commodities in certain key sectors may face financial risks due to biodiversity loss.
#
# Ignoring these risks could seriously negatively impact companies and investors, particularly those operating in industries that are highly dependent on natural capital. However, biodiversity loss can also present new opportunities for investors, such as investment growth opportunities from solutions providers that improve or preserve biodiversity.
#
# --- Bibliography ---
#
# [1] An Investor’s Guide to Biodiversity Risks.pdf | Chunk ID: 128 | Page: 1 | Similarity: 0.7667
# [2] An Investor’s Guide to Biodiversity Risks.pdf | Chunk ID: 119 | Page: 1 | Similarity: 0.6952
# [3] An Investor’s Guide to Biodiversity Risks.pdf | Chunk ID: 130 | Page: 1 | Similarity: 0.6905
# [4] An Investor’s Guide to Biodiversity Risks.pdf | Chunk ID: 124 | Page: 1 | Similarity: 0.6794
# [5] JPM_ESG_The_Long_View_Bi_2023-02-24_4342108.pdf | Chunk ID: 426 | Page: 1 | Similarity: 0.6631
#
# ================================================================================
# Question: What is the role of TNFD in biodiversity risk disclosure?
# ================================================================================
#
# Retrieving relevant documents...
# Assembling prompt for GPT...
# Querying GPT...
#
# --- Final Answer (Markdown Rendered Below) ---
#
# The Taskforce on Nature-related Financial Disclosures (TNFD) plays a crucial role in biodiversity risk disclosure by providing a standard risk-management and reporting framework for nature-related matters. The TNFD's ultimate goal is to support a shift in global financial flows to deliver a nature-positive outcome. The TNFD framework follows a similar structure to the one developed by the Taskforce on Climate-related Financial Disclosures (TCFD) for climate-related disclosures, covering entities’ governance and risk management of nature-related risks and opportunities, their impacts on the overarching strategy, as well as metrics and targets.
#
# The TNFD has also developed a structured process for reporting and management of nature-related disclosures called LEAP, which stands for Locate (your interface with nature), Evaluate (your dependencies and impacts on nature), Assess (your nature-related risks and opportunities), and Prepare (to respond to nature-related risks and opportunities and to report on your material nature-related issues).
#
# The TNFD includes a core set of 14 indicators for reporting across sectors, together with recommendations for sector-specific reporting. The framework also recommends a set of additional disclosure metrics which organizations can use where relevant. Businesses and investors that want to be TNFD-aligned would, at a minimum, report data for the core disclosure metrics.
#
# However, the TNFD framework is more complex than the TCFD because it aims to capture a broader set of linkages between companies and nature beyond financial risks and opportunities, including impacts and dependencies, and it includes extensive guidance for entities to conduct nature-related due diligence.
#
# --- Bibliography ---
#
# [1] JPM_ESG_The_Long_View_Bi_2023-02-24_4342108.pdf | Chunk ID: 355 | Page: 1 | Similarity: 0.7081
# [2] 2023-Chapter3.pdf | Chunk ID: 89 | Page: 1 | Similarity: 0.6730
# [3] An Investor’s Guide to Biodiversity Risks.pdf | Chunk ID: 127 | Page: 1 | Similarity: 0.6686
# [4] JPM_ESG_The_Long_View_Bi_2023-02-24_4342108.pdf | Chunk ID: 447 | Page: 1 | Similarity: 0.6641
# [5] JPM_ESG_The_Long_View_Bi_2023-02-24_4342108.pdf | Chunk ID: 431 | Page: 1 | Similarity: 0.6504
#
# ================================================================================
# Question: How can investors integrate biodiversity KPIs into portfolios?
# ================================================================================
#
# Retrieving relevant documents...
# Assembling prompt for GPT...
# Querying GPT...
#
# --- Final Answer (Markdown Rendered Below) ---
#
# Investors can integrate biodiversity KPIs into their portfolios through the following steps:
#
# 1. **Determine Goals**: Investors should first identify their objectives, which may include identifying companies' exposure to financial risks from biodiversity and nature loss, measuring the negative impact of investee companies on nature, meeting disclosure obligations from emerging regulations, and seizing investment opportunities related to growing demand for products and services that help tackle the biodiversity crisis.
#
# 2. **Evaluate and Reduce Exposure to Downside Financial Risk**: Investors can use available proxies, models, tools, and data to quantify biodiversity-related risk. They can evaluate exposure to nature-related physical risks such as operational or supply-chain disruptions by looking at the share of revenues or assets dependent on ecosystem services or at-risk natural commodities. They can also evaluate transition risks stemming from an evolving business environment by looking at the share of revenues or assets exposed to regulatory, legal, or reputational risks.
#
# 3. **Seek Exposure to Opportunities**: Investors can seek investment growth opportunities from solutions providers that improve or preserve biodiversity. This could be achieved by identifying companies with products that positively impact nature, such as sustainable or "regenerative" agriculture, waste management, alternative protein products, pollution prevention services, water treatment solutions, and ecosystem restoration.
#
# 4. **Evaluate and Reduce Investee Companies' Impacts on Nature**: Investors can start assessing their potential financed impacts by identifying companies whose activities could be considered key drivers of biodiversity loss. They can start with screening out activities that are considered key contributors to biodiversity loss in their portfolio, whether from a product, location, or controversy perspective. They can use geospatial data and tools to identify portfolio companies operating in biodiversity-sensitive regions. Finally, they can quantify the negative impacts of their investments on biodiversity across portfolios, sectors, or regions, a process termed biodiversity footprinting.
#
# 5. **Use of Biodiversity-Linked Instruments**: In fixed income, investors can consider green bonds with biodiversity use of proceeds and sustainability-linked bonds with biodiversity KPIs.
#
# The integration of biodiversity KPIs into portfolios is an evolving field, with new models and metrics being developed to help investors better understand and manage their biodiversity impacts and risks.
#
# --- Bibliography ---
#
# [1] An Investor’s Guide to Biodiversity Risks.pdf | Chunk ID: 129 | Page: 1 | Similarity: 0.6373
# [2] An Investor’s Guide to Biodiversity Risks.pdf | Chunk ID: 130 | Page: 1 | Similarity: 0.6332
# [3] JPM_ESG___The_Long_View__2024-09-29_4722983.pdf | Chunk ID: 460 | Page: 1 | Similarity: 0.6247
# [4] An Investor’s Guide to Biodiversity Risks.pdf | Chunk ID: 128 | Page: 1 | Similarity: 0.6221
# [5] JPM_ESG_The_Long_View_Bi_2023-02-24_4342108.pdf | Chunk ID: 374 | Page: 1 | Similarity: 0.6213
#
# ================================================================================
# Question: Examples of companies with high biodiversity risk exposure
# ================================================================================
#
# Retrieving relevant documents...
# Assembling prompt for GPT...
# Querying GPT...
#
# --- Final Answer (Markdown Rendered Below) ---
#
# Companies identified by J.P. Morgan as having high biodiversity risk exposure and being particularly strong risk managers of biodiversity-related risks include:
#
# - Solution Providers:
#     - Sappi and Danone in EMEA
#     - Kubota in Japan
#     - AGCO and Darling Ingredients in the US
#     - CMPC, Natura &Co and Suzano in LatAm
#
# - Risk Managers:
#     - Unilever and Anheuser Busch InBev in EMEA
#     - SLC Agricola in LatAm
#     - Shiseido and Lion in Japan
#
# These companies are considered to have products or services that may be beneficial to biodiversity (Solution Providers) or have explicitly considered and managed for biodiversity considerations in their operations (Risk Managers).
#
# --- Bibliography ---
#
# [1] JPM_ESG_The_Long_View_Bi_2023-02-24_4342108.pdf | Chunk ID: 357 | Page: 1 | Similarity: 0.7026
# [2] An Investor’s Guide to Biodiversity Risks.pdf | Chunk ID: 128 | Page: 1 | Similarity: 0.6984
# [3] JPM_The_Sustainable_Inve_2024-07-11_4700380.pdf | Chunk ID: 536 | Page: 1 | Similarity: 0.6814
# [4] JPM_The_Sustainable_Inve_2024-07-11_4700380.pdf | Chunk ID: 537 | Page: 1 | Similarity: 0.6622
# [5] JPM_The_Sustainable_Inve_2024-07-11_4700380.pdf | Chunk ID: 501 | Page: 1 | Similarity: 0.6617
